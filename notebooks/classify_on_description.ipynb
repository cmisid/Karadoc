# %%
import pandas as pd

# %%
df = pd.read_csv('../features/metadata/term_frequencies.csv', index_col=0)
df['tag'] = pd.read_csv('../features/tags.csv', index_col=0)['tag_name']

# %%
df
# Out:
#                                                      00  000  000th   01  \
# Invitation to Summer 2009 Rabbinic Study Semina...  0.0  0.0    0.0  0.0
# Rabbi Rachel Sabath Beit-Halachmi: Three Models...  0.0  0.0    0.0  0.0
# Shalom Hartman Institute&apos;s Innovative Theo...  0.0  0.0    0.0  0.0
# EP5:&#3585;&#3634;&#3619;&#3613;&#3633;&#3591;&...  0.0  0.0    0.0  0.0
# EP4: How to make up for acne from Bobbi Brown       0.0  0.0    0.0  0.0
# The Big Break                                       0.0  0.0    0.0  0.0
# XF3 ARMY project - promo                            0.0  0.0    0.0  0.0
# FCA 2009: Archbishop Venables                       0.0  0.0    0.0  0.0
# FCA 2009: Bishop Benn                               0.0  0.0    0.0  0.0
# FCA 2009: Interview with Archbishop Jensen and ...  0.0  0.0    0.0  0.0
# FCA 2009: Rev. Roberts                              0.0  0.0    0.0  0.0
# Carmen Trailer                                      0.0  0.0    0.0  0.0
# ...
